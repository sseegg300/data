# %% [markdown]
# <a href="https://colab.research.google.com/github/sseegg300/data/blob/main/2026%EA%B0%95%EC%84%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🌞맵플롯립
#
# *   다양한 그래프로 데이터 시각화 할수 있는 라이브러리

# %% [markdown]
# ## 1️⃣그래프 기본

# %% [markdown]
# ### 환경 설정 -  한글, 라이브러리

# %%
#한글폰트 설정
# 한글폰트 사용을 위한 koreanize-matplotlib 설치
# !pip install koreanize-matplotlib
import koreanize_matplotlib                      #한글폰트 사용을 위한 패키지 import하기
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.1 MB/s eta 0:00:00
# ...

# %%
# 시각화를 위한 패키지 import하기
import matplotlib.pyplot as plt

# %%
#(참고)Help
plt.plot?
#구글: matplotlib grid  또는  matplotlib xlabel

# %%
# x, y축에 들어갈 데이터 - 월별 몸무게 데이터
x = ['1월', '2월', '3월', '4월', '5월']
y = [56, 55, 54, 55, 57]  #단위 : kg

plt.plot(x,y)
pass                                            #plt.show()

# %% [markdown]
# ### 타이틀,축레이블(x,y),grid,legend

# %%
#타이틀
# plt.title('제목 텍스트', loc='center', pad=20, fontsize=15, color='blue')
plt.plot(x, y)
plt.title('몸무게 변화', color = 'coral', fontsize=15, pad=10 , fontweight = 'bold')
pass

# %%
#타이틀,축레이블(x,y)
plt.plot(x, y)
plt.title('몸무게 변화', color = 'colar', pad=10 , fontsize=15, fontweight = 'bold')

plt.xlabel('월',
           loc='right',      # 오른쪽 끝으로 배치
           labelpad=15,      # 축에서 15포인트만큼 아래로 띄움
           fontsize=8,
           color='darkblue',
           fontweight='bold')

plt.ylabel('몸무게(kg)',
           loc='top',        # 오른쪽 끝으로 배치
           labelpad=10,      # 축에서 15포인트만큼 아래로 띄움
           fontsize=8,
           color='red')
# Out:
# Text(0, 1, '몸무게(kg)')

# %%
#타이틀,축레이블(x,y),grid
plt.plot(x, y)
plt.title('몸무게 변화', color = 'plum', pad=10 , fontsize=15, fontweight = 'bold')

plt.xlabel('월',
           loc='right',      # 오른쪽 끝으로 배치
           labelpad=15,      # 축에서 15포인트만큼 아래로 띄움
           fontsize=8,
           color='darkblue',
           fontweight='bold')

plt.ylabel('몸무게(kg)',
           loc='top',      # 오른쪽 끝으로 배치
           labelpad=10,      # 축에서 15포인트만큼 아래로 띄움
           fontsize=8,
           color='red')
plt.grid(color='green', linestyle=':', alpha=0.5)

# %%
#범례(legend)
x = ['1월', '2월', '3월', '4월', '5월']
y = [56, 55, 54, 55, 57]  #단위 : kg

plt.plot(x,y,label='몸무게 변화데이터')
plt.legend()
plt.legend(loc='lower left',labelcolor='tomato')
plt.legend(loc=(0.5,0.5),labelcolor='tomato')          #0~1사이로  정확한 위치에 범례 위치 가능

# %% [markdown]
# ### 그래프 크기

# %%
#그래프 크기
plt.figure(figsize=(5,3))
plt.plot(x,y)

# %%
plt.figure(figsize=(3,5))
plt.plot(x,y)

# %%
plt.figure(figsize=(5,3), dpi = 150) #dots per inch 확대하고 싶을때
plt.plot(x,y)

# %% [markdown]
# ### 배경색 넣기

# %%
#배경색 넣기
plt.figure(facecolor='blue',figsize=(5,3))
plt.plot(x,y)
pass

# %%
plt.figure(facecolor='#abebd9',figsize=(5,3))  - 구글검색: color picker
plt.plot(x,y)
pass

# %%
#🎈(참고) 그래프 내부 색상 지정 방법 -
fig, ax = plt.subplots(figsize=(5, 3))    #Figure: 부모객체 / Axes: 자식객체

# 전체 배경색
fig.patch.set_facecolor('#faefe1')

# 내부 배경색
ax.set_facecolor('#e08341')
plt.plot(x,y)
plt.grid(linestyle=':', alpha=0.8)

# %%
# 그래프 저장하기 - 동일 셀에서 그리고 저장하기(/content)
plt.plot(x,y)
plt.savefig('graph.png', dpi=150)

# %% [markdown]
# ## 2️⃣꺽은선 그래프
#
# `plt.plot(x데이터,y데이터)`

# %%
# 꺾은선 그래프 - 스타일
#(1) 라인 스타일,색상,굵기,투명도
#(2) marker 모양,크기,색
import matplotlib.pyplot as plt
x = ['1월', '2월', '3월', '4월', '5월']
y = [56, 55, 54, 55, 57]  #단위 : kg

plt.plot(x, y,
         color='plum',
         linestyle='--',
         linewidth=2,
         alpha = 0.3,
         marker='s',
         markersize=10,
         markeredgecolor='red',
         markerfacecolor='gold'
)

plt.title('몸무게 변화')
plt.ylabel("kg")
plt.grid()

# %%
#포맷으로 간단하게 스타일 정하는 방법
plt.plot(x,y,'ro--')   #색상-마커모양- 선스타일

# %%
#축약어로 그리는 방법                                 (구글검색: matplotlib markerfacecolor mfc)
plt.plot(x,y,'bo--', mfc='pink', mec='green',ms=15)
plt.grid(alpha=0.5,linestyle=':')
pass

# %%
#maker에 수치를 직접 표시하는 방법 -  for 문 사용

plt.plot(x, y,
         color='plum',
         marker='s',
         linestyle='--',
         linewidth=2)

for i in range(len(x)):
  plt.text(x[i], y[i] + 0.2,          # 좌표 (x, y + 약간의 여백)
             y[i],                    # 표시할 텍스트
             fontsize=12,
             color='black')           # 세로 정렬 (bottom, top, center)

# enumerate(y): y 리스트에서 **몇 번째인지(idx)**와 **그 값(txt)**을 동시에 꺼내옴
# for i , txt in enumerate(y):
#   plt.text(x[i],y[i]+0.2,txt,fontsize=12, color='red')


plt.title('몸무게 변화')
plt.xlabel('일자')
plt.ylabel('kg')
plt.grid(True)

# %% [markdown]
# ## 3️⃣막대그래프
#
# `plt.bar(x데이터,y데이터)`
# `plt.barh(x데이터,y데이터)`

# %%
# x, y축에 들어갈 데이터
x = ['1월', '2월', '3월', '4월', '5월']
y = [80, 78, 73, 75, 76]

plt.bar(x,y,color='pink')
plt.title('월별 몸무게의 변화')
plt.grid(True)

# %%
# 막대별 다양한 컬러(컬러 리스트 활용)
x = ['1월', '2월', '3월', '4월', '5월']
y = [80, 78, 73, 75, 76]
c = ['r','g','b','pink','plum']

plt.bar(x,y, color = c, alpha = 0.5)
plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')

# %%
#y값 제약으로 비교하기 쉽게하는 방법 .ylim()
plt.bar(x,y, color = c, alpha = 0.5)
plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')
plt.ylim(60,85)
# Out:
# (60.0, 85.0)

# %%
#(그래프 기본) 축 value의 회전 표시 : .xticks() .yticks()
plt.bar(x,y, color = c, alpha = 0.5, width=0.5)
plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')
plt.ylim(60,85)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
pass

# %%
# 막대그래프 위에 글자 넣기(1)
plt.bar(x,y, color = c, alpha = 0.5, width=0.5)
plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')
plt.ylim(60,85)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

for i, txt in enumerate(y):
  plt.text(x[i],y[i]+0.2,txt, ha='center', color='green', size=8)

pass

# %%
#🎈막대그래프 위에 글자 넣기(2) - bar 각각의 데이터 활용 방법
bar = plt.bar(x,y, color = c, alpha = 0.5, width=0.5)   #bar[0],bar[1],bar[2]...

for i,rect in enumerate(bar):
  plt.text(i, rect.get_height()+0.3, y[i], ha = 'center', color='purple')

plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')
plt.ylim(60,85)
pass

# %% [markdown]
# ### 가로 막대 그래프 .barh()

# %%
# 가로 막대 그래프 그리기 barh
x = ['1월', '2월', '3월', '4월', '5월']
y = [80, 78, 73, 75, 76]
c = ['r','g','b','pink','plum']
plt.barh(x,y, color = c, alpha = 0.5)
plt.title('월별 몸무게의 변화')
plt.grid(linestyle=':')
plt.xlim(60,85)                                        # y축 범위제한을 x 축 범위제한으로 변경.
plt.xticks(rotation=45)
plt.yticks(rotation=45)
pass

# %% [markdown]
# ## 4️⃣원그래프

# %%
import matplotlib.pyplot as plt

# %%
#(🎈참고)  A ---> A형

blood_type=['AA형','AO형','BB형','BO형','O형','AB형']

#blood_type=['AA','AO','BB','BO','O','AB']
# for i, value in enumerate(blood_type):
#     blood_type[i] = value + "형"
# for i in range(len(blood_type)):
#   blood_type[i] = blood_type[i]  + "형"
blood_type
# Out:
# ['AA형', 'AO형', 'BB형', 'BO형', 'O형', 'AB형']

# %%
# 샘플데이터  : 100명 중 혈액형별 인원의 비율
# 파이차트
#plt.pie?
blood_type=['AA형','AO형','BB형','BO형','O형','AB형']
count=[20,25,20,15,15,5]


#plt.pie(count)
#plt.pie(count,labels=blood_type)
#plt.pie(count,labels=blood_type, autopct='%.1f')
#plt.pie(count,labels=blood_type, autopct='%.1f%%') # %붙히기
#plt.pie(count,labels=blood_type, autopct='%.1f%%', explode=[0.05,0,0,0])
#plt.pie(count,labels=blood_type, autopct='%.1f%%', explode=[0.05]*4)
#plt.pie(count,labels=blood_type, autopct='%.1f%%', explode=[0.05,0,0,0],startangle=90,counterclock=False)
#plt.legend()   #loc=(1,1) : 우측 맨 위 위치
#plt.legend(loc=(1,0.7))

#startangle=90 :파이 차트의 시작 각도를 설정,기본값은 0도(3시 방향), 90도:12시 방향
#counterclock=False :시계반대방향으로

plt.pie(count,
        labels=blood_type,
        autopct='%1.1f%%',
        explode=[0.05,0,0,0,0,0],
        startangle=90,
        counterclock=False
        )
plt.legend(loc=(1,0.7))
plt.title('혈액형별 인원의 비율')
plt.show()

# %%
blood_type=['AA형','AO형','BB형','BO형','O형','AB형']
count=[20,25,20,15,15,5]
colors = ['#e89bd0','#70cf89','#f2f7ab','#99b3e8','#a9ed74','#b57d84']

plt.pie(count,
        labels=blood_type,
        colors=colors,
        autopct='%1.1f%%',
#  explode=[0.05,0,0,0,0,0],
        startangle=90,
        counterclock=False,
        wedgeprops={'width': 0.5, 'edgecolor': 'w', 'linewidth': 5},           #전체 파이두께(1:not 도넛)
        textprops={'fontsize': 10, 'color': '#0a55f0', 'fontweight': 'bold'},
        pctdistance=0.8
        )
plt.legend(loc=(1.1,0.6))
plt.title('혈액형별 인원의 비율')
plt.show()

# %%
# 🎈함수 적용  낮은% 레이블은 나타내지 않기
def skip_autopct(p):
  return f'{p:.1f}%' if p >=10 else ''

 #return ('%.1%%' %p) if p >=10 else ''
 #return'{.1f}%'.format(p) if p > 10 else ''

plt.pie(count,
        labels=blood_type,
        colors=colors,
        startangle=90,
        counterclock=False,
        autopct=skip_autopct,
        wedgeprops={'width': 0.5, 'edgecolor': 'w', 'linewidth': 5}, #전체 파이두께(1:not 도넛)
        textprops={'fontsize': 12, 'color': '#0a55f0', 'fontweight': 'bold'},
        pctdistance=0.7
        )
plt.legend(loc=(1.1,0.6))
plt.title('혈액형별 인원의 비율')
plt.show()

# %% [markdown]
# ## 5️⃣산점도
# `scatter(x데이터,y데이터)`

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### k-scores데이터 활용

# %%
# k-scores 데이터 활용
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/sseegg300/data/refs/heads/main/k-scores.csv')
df['번호']=['1번','2번','3번','4번','5번','6번','7번']
df.set_index('번호', inplace=True)
df
# Out:
#      이름   학교  학년    키     국어     영어     수학    과학  사회          특기 동아리
# 번호
# 1번  장원영  청담고   1  173   90.0  100.0   85.0  88.0  92        영상편집  댄스
# 2번  카리나  팔달고   2  168   85.0   90.0   92.0   NaN  88     이모티콘 제작  실험
# 3번  차은우  수리고   2  183  100.0   95.0  100.0  98.0  96          보컬  실험
# 4번   민지  부산고   3  169   92.0    NaN    NaN  85.0  90       게임 제작  댄스
# 5번   정국  부산고   1  178   75.0   80.0    NaN  72.0  85  C++/Python  독서
# 6번    뷔  청담고   3  179   82.0   85.0   65.0  70.0  78    수학 문제 풀이  독서
# 7번   제니  청담고   3  163    NaN  100.0    NaN  92.0  94      3D 모델링  댄스

# %%
#국어,수학의 null 값을 각 과목의 평균점수로 채움
df['국어'] = df['국어'].fillna(int(df['국어'].mean()))
df['수학'] = df['수학'].fillna(int(df['수학'].mean()))
df
# Out:
#      이름   학교  학년    키     국어     영어     수학    과학  사회          특기 동아리
# 번호
# 1번  장원영  청담고   1  173   90.0  100.0   85.0  88.0  92        영상편집  댄스
# 2번  카리나  팔달고   2  168   85.0   90.0   92.0   NaN  88     이모티콘 제작  실험
# 3번  차은우  수리고   2  183  100.0   95.0  100.0  98.0  96          보컬  실험
# 4번   민지  부산고   3  169   92.0    NaN   85.0  85.0  90       게임 제작  댄스
# 5번   정국  부산고   1  178   75.0   80.0   85.0  72.0  85  C++/Python  독서
# 6번    뷔  청담고   3  179   82.0   85.0   65.0  70.0  78    수학 문제 풀이  독서
# 7번   제니  청담고   3  163   87.0  100.0   85.0  92.0  94      3D 모델링  댄스

# %%
#산점도 marker/단일크기
plt.scatter(df['국어'],df['수학'],marker='*',s=300,color ='tomato')
plt.xlabel('국어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
#산점도 marker/크기/단일 색상 - 사이즈를 학년에 따라 다르게 표시

sizes=df['학년']*300

plt.scatter(df['국어'],df['수학'],marker='o',s=sizes, color = 'darkviolet',)
plt.xlabel('국어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
#cmap색상,colorbar()

sizes=df['학년']*300

plt.scatter(df['국어'],df['수학'],marker='o',s=sizes, c=df['학년'],cmap='Spectral')
plt.xlabel('국어점수')
plt.ylabel('수학점수')
plt.colorbar(ticks=[1,2,3], label='학년',shrink=0.5)                                  #컬러바의 전체적인 크기(길이)를 조절하는 비율값
pass

# %% [markdown]
# ### seaborn 데이터 활용(펭귄/항공)
# **:penguins**
# (펭귄데이터)
# *   펭귄의 종(species), 서식지(island), 부리 길이, 날개 길이, 몸무게등
# *   "**날개가 길면 몸무게도 많이 나갈까?**"
#
# **:flights**
# (항공 승객 데이터)
# *   year (연도), month (월), passengers (승객 수)등
# *   "**시간이 지날수록 비행기를 타는 사람이 늘어나고 있을까**?"
# *   "**매년 몇 월에 사람들이 여행을 가장 많이 갈까?**"

# %%
#샘플데이터 seaborm 에서 가져오기
import seaborn as sns

# 사용 가능한 모든 데이터셋 이름 출력
dataset_names = sns.get_dataset_names()
print(dataset_names)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# 데이터 확인
# 전체정보 확인 .info()
# 컬럼명만 확인 .column()

# %%
# 데이터 확인
#penguins.info()
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# 샘플데이터
import seaborn as sns
penguins = sns.load_dataset('penguins')[['flipper_length_mm', 'body_mass_g']]
penguins.columns = ['날개 길이(mm)', '무게(g)']
penguins
# Out:
#      날개 길이(mm)   무게(g)
# 0        181.0  3750.0
# 1        186.0  3800.0
# 2        195.0  3250.0
# 3          NaN     NaN
# 4        193.0  3450.0
# ..         ...     ...
# 339        NaN     NaN
# 340      215.0  4850.0
# 341      222.0  5750.0
# 342      212.0  5200.0
# 343      213.0  5400.0
#
# [344 rows x 2 columns]

# %%
x = penguins['날개 길이(mm)']
y = penguins['무게(g)']
x
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3        NaN
# 4      193.0
#        ...
# 339      NaN
# 340    215.0
# 341    222.0
# 342    212.0
# 343    213.0
# Name: 날개 길이(mm), Length: 344, dtype: float64

# %% [markdown]
# <참고>
# c=y라고 쓰면 각 데이터 포인트의 y값 크기에 따라 색상을 다르게 칠해라라는 명령
#
# 작동 원리: y 리스트의 최솟값과 최댓값을 자동으로 계산하여, cmap으로 지정한 색상표(여기서는 'plasma')의 양 끝단에 대응

# %%
plt.scatter(x,y,
            c=y,
            marker='s')   #도움말 참조
plt.title('<펭귄의 날개길이 & 무게>',pad=20,fontsize=15)
plt.xlabel('날개길이(mm)')
plt.ylabel('무게(g)')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.colorbar(label='몸무게 (kg)') # 컬러바 추가
plt.show() #:화면이 깔끔하게 정리됨.

# %%
plt.scatter(x,y,
            marker='s',
            color = 'gold',
            edgecolors='black')
plt.title('<펭귄의 날개길이 & 무게>',pad=20,fontsize=15)
plt.xlabel('날개길이(mm)')
plt.ylabel('무게(g)')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.show() #:화면이 깔끔하게 정리됨.

# %%
import seaborn as sns

flights = sns.load_dataset('flights')
flights.info()
flights.columns

flights.columns = ['년도', '월','승객수']
flights.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB
# Index(['년도', '월', '승객수'], dtype='object')

# %%
flights.columns
# Out:
# Index(['년도', '월', '승객수'], dtype='object')

# %%
# <<참고 명령어>>
#import matplotlib.pyplot as plt
#flights.plot.box()
#flights["승객수"].plot.box()


flights.plot.scatter("년도", "승객수", alpha=0.5)
#plt.scatter(flights['년도'],flights['승객수'], alpha=0.5)
# Out:
# <Axes: xlabel='년도', ylabel='승객수'>

# %%
# 년도별 승액수 산점도 그래프
plt.scatter(flights['년도'],flights['승객수'],
            c=flights['승객수'],
            marker='o',
            cmap='viridis')
plt.title('<년도별 승객수>',pad=20,fontsize=15)
plt.xlabel('년도')
plt.ylabel('승객수')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.colorbar(label='승객수') # 컬러바 추가
plt.show() #:화면이 깔끔하게 정리됨.

# %%
# 월별 승액수 산점도 그래프
plt.scatter(flights['월'],flights['승객수'],
            c=flights['승객수'],
            marker='o',
            cmap='OrRd')
plt.title('<월별 승객수>',pad=20,fontsize=15)
plt.xlabel('월')
plt.ylabel('승객수')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.colorbar(label='승객수') # 컬러바 추가
plt.show() #:화면이 깔끔하게 정리됨.

# %% [markdown]
# ## 6️⃣여러 그래프(1 subplot)

# %% [markdown]
# ### k-scores 데이터 활용

# %%
# k-scores 데이터 활용
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/sseegg300/data/refs/heads/main/k-scores.csv')
df['번호']=['1번','2번','3번','4번','5번','6번','7번']
df.set_index('번호', inplace=True)
df
# Out:
#      이름   학교  학년    키     국어     영어     수학    과학  사회          특기 동아리
# 번호
# 1번  장원영  청담고   1  173   90.0  100.0   85.0  88.0  92        영상편집  댄스
# 2번  카리나  팔달고   2  168   85.0   90.0   92.0   NaN  88     이모티콘 제작  실험
# 3번  차은우  수리고   2  183  100.0   95.0  100.0  98.0  96          보컬  실험
# 4번   민지  부산고   3  169   92.0    NaN    NaN  85.0  90       게임 제작  댄스
# 5번   정국  부산고   1  178   75.0   80.0    NaN  72.0  85  C++/Python  독서
# 6번    뷔  청담고   3  179   82.0   85.0   65.0  70.0  78    수학 문제 풀이  독서
# 7번   제니  청담고   3  163    NaN  100.0    NaN  92.0  94      3D 모델링  댄스

# %%
#국어,수학의 null 값을 각 과목의 평균점수로 채움
df['국어'] = df['국어'].fillna(int(df['국어'].mean()))
df['수학'] = df['수학'].fillna(int(df['수학'].mean()))
df['영어'] = df['영어'].fillna(int(df['영어'].mean()))

# %%
df
# Out:
#      이름   학교  학년    키     국어     영어     수학    과학  사회          특기 동아리
# 번호
# 1번  장원영  청담고   1  173   90.0  100.0   85.0  88.0  92        영상편집  댄스
# 2번  카리나  팔달고   2  168   85.0   90.0   92.0   NaN  88     이모티콘 제작  실험
# 3번  차은우  수리고   2  183  100.0   95.0  100.0  98.0  96          보컬  실험
# 4번   민지  부산고   3  169   92.0   91.0   85.0  85.0  90       게임 제작  댄스
# 5번   정국  부산고   1  178   75.0   80.0   85.0  72.0  85  C++/Python  독서
# 6번    뷔  청담고   3  179   82.0   85.0   65.0  70.0  78    수학 문제 풀이  독서
# 7번   제니  청담고   3  163   87.0  100.0   85.0  92.0  94      3D 모델링  댄스

# %%
plt.plot(df['이름'],df['국어'],
         marker='o',
         color='red',
         label='국어'
)
plt.plot(df['이름'],df['영어'],
         marker='o',
         color='blue',
         label='영어'
)
plt.plot(df['이름'],df['수학'],
         marker='o',
         color='green',
         label='수학'
)
plt.title('<시험 성적(국영수)>',pad=20,fontsize=15)
plt.xlabel('이름')
plt.ylabel('점수')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.legend(loc='lower left', fontsize=10, shadow=True, ncol=3)
plt.show()

# %% [markdown]
# ### seaborn 항공 승객 데이터 활용

# %%
#seaborn 항공 승객 데이터
import seaborn as sns

flights = sns.load_dataset('flights')
flights.info()
flights.columns

flights.columns = ['년도', '월','승객수']
flights.columns

# %%
# 특정년도의 월별 승객수 선 그래프
f_1960 = flights[flights['년도'] == 1960]
f_1956 = flights[flights['년도'] == 1956]
f_1950 = flights[flights['년도'] == 1950]
plt.plot(f_1960['월'],f_1960['승객수'],
         marker='o',
         color='red',
         label='1960년'
)
plt.plot(f_1956['월'],f_1956['승객수'],
         marker='o',
         color='green',
         label='1956년'
)
plt.plot(f_1950['월'],f_1950['승객수'],
         marker='o',
         color='blue',
         label='1950년'
)
plt.title('<월별 승객수>',pad=20,fontsize=15)
plt.xlabel('월')
plt.ylabel('승객수')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.legend(title='연도별', loc='upper left', fontsize=10, shadow=True)
plt.show() #:화면이 깔끔하게 정리됨.

# %%
# 특정년도의 월별 승객수 선 그래프(수치표현)
f_1960 = flights[flights['년도'] == 1960]
f_1956 = flights[flights['년도'] == 1956]
f_1950 = flights[flights['년도'] == 1950]
plt.plot(f_1960['월'],f_1960['승객수'],
         marker='o',
         color='red',
         label='1960년'
)

for i,txt in enumerate(f_1956['승객수']):
  plt.text(f_1956['월'].iloc[i], txt + 15, txt, fontsize=7)

plt.plot(f_1956['월'],f_1956['승객수'],
         marker='o',
         color='green',
         label='1956년'
)

for i,txt in enumerate(f_1960['승객수']):
  plt.text(f_1960['월'].iloc[i], txt + 15, txt, fontsize=7)

plt.plot(f_1950['월'],f_1950['승객수'],
         marker='o',
         color='blue',
         label='1950년'
)

for i,txt in enumerate(f_1950['승객수']):
  plt.text(f_1950['월'].iloc[i], txt + 15, txt, fontsize=7)

plt.title('<월별 승객수>',pad=20,fontsize=15)
plt.xlabel('월')
plt.ylabel('승객수')
plt.grid(True, linestyle='--', alpha=0.5) #alpha는 투명도 0.0에서 1.0
plt.legend(title='연도별', loc='upper left', fontsize=10, shadow=True)
plt.show() #:화면이 깔끔하게 정리됨.

# %% [markdown]
# ## 7️⃣히스토그램
#
# `plt.hist(데이터)`

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 30            4.8          3.1           1.6          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 132           6.4          2.8           5.6          2.2  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 145           6.7          3.0           5.2          2.3  virginica

# %%
plt.hist?

# %%
# 히스토그램
plt.hist(iris['sepal_length'],bins=20,label='sepal_length',alpha=0.5)
plt.hist(iris['petal_length'],bins=20,label='petal_length',alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ## 8️⃣복합 그래프(n subplots)

# %%
# k-idol 데이터 활용
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/sseegg300/data/refs/heads/main/k-scores.csv')
df['번호']=['1번','2번','3번','4번','5번','6번','7번']
df.set_index('번호', inplace=True)

df.fillna(0,inplace=True)  #결측치 처리

# %%
#학년별 수 파악
df1 = df.groupby('학년').size()
df1
# Out:
# 학년
# 1    2
# 2    2
# 3    3
# dtype: int64

# %%
fig,axs = plt.subplots(2,2, figsize=(20,15))  #2 x 2  부모,자식
fig.suptitle('복합 그래프', size = 30)
fig.patch.set_facecolor('#fae8fa')

#첫번째 그래프(막대그래프)
axs[0,0].bar(df['이름'],df['국어'], label='국어점수')
axs[0,0].set_title('국어점수',pad=20,size = 20)
axs[0,0].legend()
axs[0,0].grid(linestyle='--')
axs[0,0].set(xlabel='이름', ylabel='점수')
axs[0,0].set_facecolor('lightgreen')

#두번째 그래프(선그래프)
axs[0,1].plot(df['이름'],df['수학'], linewidth=3, marker='o', markersize=10,label='수학점수')
axs[0,1].plot(df['이름'],df['영어'], linewidth=3, marker='^', markersize=10, label='영어점수')
axs[0,1].set_title('수학/영어 점수', pad=20, size = 20)
axs[0,1].legend()
axs[0,1].grid(linestyle='--')
axs[0,1].set(xlabel='이름', ylabel='점수')
axs[0,1].set_facecolor('lightyellow')

#세번째 그래프(원그래프)
df1 = df.groupby('학년').size()

axs[1,0].pie(df1,
             labels=['1학년','2학년','3학년'],
             autopct='%.0f%%',
             colors=['lightgreen','pink','lightyellow'],
             textprops={'fontsize': 20, 'color': '#0a55f0', 'fontweight': 'bold'},
             pctdistance=0.7
            )
axs[1,0].set_title('학년별 비율',pad=10,size = 20)
axs[1,0].legend()

#네번째 그래프(산점도)
sizes=df['학년']*300

axs[1,1].scatter(df['국어'],df['수학'],marker='o',s=sizes, c=df['학년'],cmap='Spectral')
axs[1,1].set_title('국어수학 산점도', pad=20, size = 20)
axs[1,1].grid(linestyle='--')
axs[1,1].set(xlabel='국어', ylabel='수학')
axs[1,1].set_facecolor('lightblue')
pass

# %% [markdown]
# # 🎯연습문제

# %% [markdown]
# ##  성적 데이터 시각화(1)

# %%
# k-idol 데이터 활용
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/sseegg300/data/refs/heads/main/k-scores.csv')
df['번호']=['1번','2번','3번','4번','5번','6번','7번']
df.set_index('번호', inplace=True)

#*필요한 DF로 슬라이싱
df = df[['이름','국어','영어','수학']]

# %%
df
# Out:
#      이름     국어   영어     수학
# 번호
# 1번  장원영   90.0  100   85.0
# 2번  카리나   85.0   90   92.0
# 3번  차은우  100.0   95  100.0
# 4번   민지    NaN   92    NaN
# 5번   정국   75.0   80    NaN
# 6번    뷔   82.0   85   65.0
# 7번   제니    NaN  100    NaN

# %%
# 학생별 국어점수
plt.bar(df['이름'],df['국어'],color = 'plum')
plt.title('<학생들 국어 점수>',pad=10)
plt.ylabel('국어점수')

#bar에 점수 표시하기
x=df['이름']
y=df['국어']

for i,txt in enumerate(y):
  plt.text(x.iloc[i], txt + 1,      # DF의 x축 인덱스별 값 가져오기  .iloc[] 사용 :  리스트와 차이남.
             txt,
             fontsize=9,
             horizontalalignment='center',   #ha='center'
             color='blue')
plt.show()

# %%
# 학생별 영어점수
plt.bar(df['이름'],df['영어'],color = 'salmon',edgecolor='black')
plt.title('<학생들 영어 점수>',pad=10)
plt.ylabel('영어점수')

#bar에 점수 표시하기
x=df['이름']
y=df['영어']
# for i in range(len(x)):
#   plt.text(x.iloc[i], y.iloc[i] + 1,      # 좌표 (x, y + 약간의 여백)
#              y.iloc[i],             # 표시할 텍스트
#              fontsize=9,
#              horizontalalignment='center',
#              color='blue')

for i,txt in enumerate(y):
  plt.text(x.iloc[i], txt + 1,
             txt,
             fontsize=9,
             ha='center',
             color='blue')

# %%
# 학생별 수학점수
plt.bar(df['이름'],df['수학'],color = 'lavender',edgecolor='violet')
plt.title('<학생들 수학 점수>',pad=10)
plt.ylabel('수학점수')

#bar에 점수 표시하기
x=df['이름']
y=df['수학']
for i,txt in enumerate(y):
  plt.text(x.iloc[i], txt + 1,
             txt,
             fontsize=9,
             ha='center',
             color='blue')

# %%
df.loc['1번', '이름'] = 'Jack'

# %%
df
# Out:
#       이름     국어   영어     수학
# 번호
# 1번  Jack   90.0  100   85.0
# 2번   카리나   85.0   90   92.0
# 3번   차은우  100.0   95  100.0
# 4번    민지    NaN   92    NaN
# 5번    정국   75.0   80    NaN
# 6번     뷔   82.0   85   65.0
# 7번    제니    NaN  100    NaN

# %%
# 결측치 처리(그래프상의 점수를 정수화)
df = df.fillna(0)
df
# Out:
#      이름     국어   영어     수학
# 번호
# 1번  장원영   90.0  100   85.0
# 2번  카리나   85.0   90   92.0
# 3번  차은우  100.0   95  100.0
# 4번   민지    0.0   92    0.0
# 5번   정국   75.0   80    0.0
# 6번    뷔   82.0   85   65.0
# 7번   제니    0.0  100    0.0

# %% [markdown]
# ##  성적 데이터 시각화(2)

# %%
# 학생별 평균점수 컬럼 추가
avg = round((df['국어']+df['영어']+df['수학'])/3,2)
type(avg)
df['평균']= avg
df
# Out:
#      이름     국어   영어     수학     평균
# 번호
# 1번  장원영   90.0  100   85.0  91.67
# 2번  카리나   85.0   90   92.0  89.00
# 3번  차은우  100.0   95  100.0  98.33
# 4번   민지    0.0   92    0.0  30.67
# 5번   정국   75.0   80    0.0  51.67
# 6번    뷔   82.0   85   65.0  77.33
# 7번   제니    0.0  100    0.0  33.33

# %%
# 학생별 등수 컬럼 추가
df['등수']=df['평균'].rank(ascending=False).astype(int)
df
# Out:
#      이름     국어   영어     수학     평균  등수
# 번호
# 1번  장원영   90.0  100   85.0  91.67   2
# 2번  카리나   85.0   90   92.0  89.00   3
# 3번  차은우  100.0   95  100.0  98.33   1
# 4번   민지    0.0   92    0.0  30.67   7
# 5번   정국   75.0   80    0.0  51.67   5
# 6번    뷔   82.0   85   65.0  77.33   4
# 7번   제니    0.0  100    0.0  33.33   6

# %%
# 학생별 평균점수 시각화
plt.bar(df['이름'],df['평균'],color='tomato',edgecolor='red')
plt.title('학생별 평균점수에 따른 등수')
for i in range(len(df['이름'])):
  plt.text(df['이름'].iloc[i], df['평균'].iloc[i] + 1.3,
             f"{int(df['등수'].iloc[i])}등",
             fontsize=7,
             ha='center',
             color='blue')
pass

# %% [markdown]
# ##  성적 데이터 시각화(3) - 여러그래프

# %%
# 학생별 국어,영어,수학 점수 다중막대그래프(1)

plt.plot(df['이름'],df['수학'],label='수학',marker="^",color='green')
plt.plot(df['이름'],df['국어'],label='국어',marker="o",color='blue')
plt.plot(df['이름'],df['영어'],label='영어',marker="*",color='red')

plt.legend(loc='upper center')
pass

# %%
# 학생별 국어,영어,수학 점수 다중막대그래프(1)
# ==> matplptlib에서는 구분이 안됨:❌
# 각 Bar의 width와 x위치 변경으로 조정할수 있으나, 컬럼수가 많으면 더 어려워짐

plt.bar(df['이름'],df['수학'],label='수학',color='green',alpha=0.5)
plt.bar(df['이름'],df['국어'],label='국어',color='blue',alpha=0.5)
plt.bar(df['이름'],df['영어'],label='영어',color='red',alpha=0.5)

plt.legend(loc='upper center')
pass

# %%
# 🎈학생별 국어,영어,수학 점수 다중막대그래프(2) - pandas 시각화 함수 활용
#df.plot(x= , y= ,kind='그래프의 종류')
#df.plot()
df.plot(x='이름',y=['국어','영어','수학'],kind='bar',title='학생성적비교')
pass

# %% [markdown]
# # 🎯연습문제

# %%
ott_data = {
    '콘텐츠명': ['오징어 게임 2', '더 글로리', '무빙', '피지컬: 100', '환승연애', '흑백요리사', '카지노'],
    '플랫폼': ['Netflix', 'Netflix', 'Disney+', 'Netflix', 'TVING', 'Netflix', 'Disney+'],
    '개봉년도': [2024, 2022, 2023, 2023, 2021, 2024, 2022],
    '시청시간': [16.5, 6.2, 5.8, 2.1, 1.5, 4.8, 3.2],    #(단위:억)
    '평점': [9.2, 9.5, 9.7, 8.8, 9.1, 9.4, 8.9]
}

df = pd.DataFrame(ott_data)
df
# Out:
#        콘텐츠명      플랫폼  개봉년도  시청시간   평점
# 0  오징어 게임 2  Netflix  2024  16.5  9.2
# 1     더 글로리  Netflix  2022   6.2  9.5
# 2        무빙  Disney+  2023   5.8  9.7
# 3  피지컬: 100  Netflix  2023   2.1  8.8
# 4      환승연애    TVING  2021   1.5  9.1
# 5     흑백요리사  Netflix  2024   4.8  9.4
# 6       카지노  Disney+  2022   3.2  8.9

# %%
#✅[문제1] 막대그래프 그리기(X:콘텐츠명, Y:평점)
plt.figure(figsize=(5,3))
plt.bar(df['콘텐츠명'],df['평점'],color='pink')

pass

# %%
#✅[문제2] 그래프 제목,x,y축 라벨을 적용해서 막대그래프를 완성 하세요.

# 제목:<콘텐츠별 평점>
# x축 label: 콘텐츠명(30도 회전)
# y축 label: 평점

plt.figure(figsize=(5,3))
plt.bar(df['콘텐츠명'],df['평점'],color='pink')
plt.xlabel('콘텐츠명')
plt.ylabel('평점')
plt.xticks(rotation=30, size=7)
plt.title('<콘텐츠별 평점>')

for i,value in enumerate(df['평점']):
  plt.text(df['콘텐츠명'].iloc[i],value + 0.3, value,ha='center', size=8)

# %%
#✅[문제3] 개봉년도별 평균시청시간 변화를 선그래프로 그려보세요.
#[문제3-1] 개봉년도별로 groupby를 해서 평균값(.mean())을 먼저 구하시오
df_group = df.groupby('개봉년도').mean(numeric_only=True)
df_group
# Out:
#        시청시간    평점
# 개봉년도
# 2021   1.50  9.10
# 2022   4.70  9.20
# 2023   3.95  9.25
# 2024  10.65  9.30

# %%
#✅[문제3] 개봉년도별 평균시청시간 변화를 선그래프로 그려보세요.
#[문제3-2] 선그래프 그리기
plt.plot(df_group.index,df_group['시청시간'])
pass

# %%
#✅[문제3] 개봉년도별 평균시청시간 변화를 선그래프로 그려보세요.
#[문제3-3]  위 선그래프 아래 조건에 맞게 그려주세요.

# 제목:<년도별 평균시청시간>
# x축 label: 년도
# y축 label: 시간(단위:억)
# marker:'o'
# x축눈금(2021,2022,2023,2024)

plt.plot(df_group.index,df_group['시청시간'],marker='o',markersize=10)
plt.title('<년도별 평균시청시간>')
plt.xlabel('년도')
plt.ylabel('시간(단위:억)')
plt.xticks([2021,2022,2023,2024])
pass

# %%
#✅[문제4] 플랫폼별 콘텐츠 갯수를 원 그래프로 나타내 보세요.
#[문제4-1] .groupby('플랫폼').size()

df_group = df.groupby('플랫폼').size()
df_group
# Out:
# 플랫폼
# Disney+    2
# Netflix    4
# TVING      1
# dtype: int64

# %%
#✅[문제4] 플랫폼별 콘텐츠 갯수를 원 그래프로 나타내 보세요.
#[문제4-2] 원그래프
plt.pie(df_group)
pass

# %%
#✅[문제4] 플랫폼별 콘텐츠 갯수를 원 그래프로 나타내 보세요.
#[문제4-3] 위 원그래프 아래 조건에 맞게 그려주세요.

# 제목:<플랫폼별 콘텐츠수 비율>
# 색상 리스트 활용해서 색상 변경 colors = [ '#88db9e' , '#aea7e8' , '#f7f7a6' ]
colors = [ '#88db9e' , '#aea7e8' , '#f7f7a6' ]
plt.pie(df_group,
        labels=df_group.index,
        autopct='%1.0f%%',
        colors= colors
        )
plt.legend(loc=(1,0.7))
plt.title('<플랫폼별 콘텐츠수 비율>')
plt.show()
