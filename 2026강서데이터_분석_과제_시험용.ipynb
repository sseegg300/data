# %% [markdown]
# <a href="https://colab.research.google.com/github/sseegg300/data/blob/main/2026%EA%B0%95%EC%84%9C%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_%EA%B3%BC%EC%A0%9C_%EC%8B%9C%ED%97%98%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎯데이터분석 과제
#
# *   🚩부분은 반드시 먼저 실행하세요.
# *   공유 > 일반 엑세스를 반드시 '링크가 있는 모든 사용자'로 수정한 다음 링크를 복사해서 제출하세요.

# %%
#🚩반드시 실행하기.
# !pip install koreanize-matplotlib
import koreanize_matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %%
#🚩데이터프레임 만들기
ott_data = {
    '콘텐츠명': ['오징어 게임 2', '더 글로리', '무빙', '피지컬: 100', '환승연애', '흑백요리사', '카지노'],
    '플랫폼': ['Netflix', 'Netflix', 'Disney+', 'Netflix', 'TVING', 'Netflix', 'Disney+'],
    '개봉년도': [2024, 2022, 2023, 2023, 2021, 2024, 2022],
    '시청시간': [16.5, 6.2, 5.8, 2.1, 1.5, 4.8, 3.2],    #(단위:억)
    '평점': [9.2, 9.5, 9.7, 8.8, 9.1, 9.4, 8.9]
}

df = pd.DataFrame(ott_data)
df

# %%
#✅[문제1] 콘텐츠명만 출력해 보세요
# Out:
# 0    오징어 게임 2
# 1       더 글로리
# 2          무빙
# 3    피지컬: 100
# 4        환승연애
# 5       흑백요리사
# 6         카지노
# Name: 콘텐츠명, dtype: object

# %%
#✅[문제2] 콘텐츠명,플랫폼을 출력해 보세요
# Out:
#        콘텐츠명      플랫폼
# 0  오징어 게임 2  Netflix
# 1     더 글로리  Netflix
# 2        무빙  Disney+
# 3  피지컬: 100  Netflix
# 4      환승연애    TVING
# 5     흑백요리사  Netflix
# 6       카지노  Disney+

# %%
#✅[문제3] 추천점수 Column을 추가 하세요.
# 추천점수 = (시청시간*평점)//10
# Out:
#        콘텐츠명      플랫폼  개봉년도  시청시간   평점  추천점수
# 0  오징어 게임 2  Netflix  2024  16.5  9.2  15.0
# 1     더 글로리  Netflix  2022   6.2  9.5   5.0
# 2        무빙  Disney+  2023   5.8  9.7   5.0
# 3  피지컬: 100  Netflix  2023   2.1  8.8   1.0
# 4      환승연애    TVING  2021   1.5  9.1   1.0
# 5     흑백요리사  Netflix  2024   4.8  9.4   4.0
# 6       카지노  Disney+  2022   3.2  8.9   2.0

# %%
#✅[문제4] 막대그래프 그리기(X:콘텐츠명, Y:평점)
#figsize는(5,3)으로 설정해주세요.

# %%
#✅[문제5] 그래프 제목,x,y축 라벨을 적용해서 [문제4]의 막대그래프를 완성 하세요.

# 막대그래프의 색상은 자유색상으로 지정
# 제목:<콘텐츠별 평점>
# x축 label: 콘텐츠명(30도 회전)
# y축 label: 평점
# Out:
# Text(0.5, 1.0, '<콘텐츠별 평점>')

# %%
#✅[문제6] [문제5]의 그래프에 각 막대중간에 값을 표시하시오.(for문 사용)

# %%
#🚩 7번 문제를 해결하기 위해 먼제 실행하세요.
#플랫폼별 콘텐츠 갯수를 구하는 DataFrame 구하기 위해 해당 셀을 실행하시오.
# DataFrame명은 df_group임.

df_group = df.groupby('플랫폼').size()
df_group
# Out:
# 플랫폼
# Disney+    2
# Netflix    4
# TVING      1
# dtype: int64

# %%
#✅[문제7] 플랫폼별 콘텐츠 갯수를 원 그래프로 나타내 보세요.

# %%
#✅[문제8] 플랫폼별 콘텐츠 갯수를 원 그래프로 나타내 보세요.
#[문제7] 위 원그래프 아래 조건에 맞게 그려주세요.

# 색상 리스트 활용해서 색상 변경 colors = [ '#88db9e' , '#aea7e8' , '#f7f7a6' ]
# 제목:<플랫폼별 콘텐츠수 비율>
# (Hint) 범례 레이블은 labels =  df_group.index
